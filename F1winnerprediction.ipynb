# %% [markdown]
# <a href="https://colab.research.google.com/github/MansiiKhandekar/MansiiKhandekar/blob/main/F1winnerprediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install fastf1
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 151.2/151.2 kB 5.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.4/61.4 kB 5.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 164.8/164.8 kB 14.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 61.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.4/69.4 kB 6.4 MB/s eta 0:00:00
# ...
#   Attempting uninstall: websockets
#     Found existing installation: websockets 15.0.1
#     Uninstalling websockets-15.0.1:
#       Successfully uninstalled websockets-15.0.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# dataproc-spark-connect 0.7.5 requires websockets>=14.0, but you have websockets 13.1 which is incompatible.
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
cache_path = '/content/drive/MyDrive/fastf1_cache'

if not os.path.exists(cache_path):
    os.makedirs(cache_path)

import fastf1
fastf1.Cache.enable_cache(cache_path)

# %%
cache_path = '/content/drive/MyDrive/fastf1_cache'
fastf1.Cache.enable_cache(cache_path)

# %%
import pandas as pd

# %%
import fastf1

# %%
import fastf1.core as fc
from fastf1 import get_session
data=get_session(2024,"Canada",'Q')
data.load()
data.session_info
# Out:
# core           INFO 	Loading data for Canadian Grand Prix - Qualifying [v3.5.3]
# INFO:fastf1.fastf1.core:Loading data for Canadian Grand Prix - Qualifying [v3.5.3]
# req            INFO 	Using cached data for session_info
# INFO:fastf1.fastf1.req:Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# INFO:fastf1.fastf1.req:Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# INFO:fastf1.fastf1.req:Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# INFO:fastf1.fastf1.req:Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# INFO:fastf1.fastf1.req:Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# INFO:fastf1.fastf1.req:Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# ...

# %%
data_q=get_session(2024,"Canada",'Q')
data_r=get_session(2024,"Canada",'R')
data_q.load()
data_r.load()
laps_q=data_q.laps
laps_r=data_r.laps
res_q=data_q.results
res_r=data_r.results

# %%
laps_q=laps_q[['DriverNumber','LapTime','Sector1Time','Sector2Time','Sector3Time','SpeedFL','SpeedST']]
laps_r=laps_r[['DriverNumber','LapTime','Sector1Time','Sector2Time','Sector3Time','SpeedFL','SpeedST']]
res_q=res_q[['DriverNumber','GridPosition','Q1','Q2','Q3','Position']]
res_r=res_r[['DriverNumber','GridPosition','Q1','Q2','Q3','Position']]

# %%
laps_q.columns
# Out:
# Index(['DriverNumber', 'LapTime', 'Sector1Time', 'Sector2Time', 'Sector3Time',
#        'SpeedFL', 'SpeedST'],
#       dtype='object')

# %%
laps_q
for i in [laps_r,laps_q]:
 for col in ['LapTime','Sector1Time','Sector2Time','Sector3Time']:
  #i[col]=i[col].fillna(laps_q[col].mean())
  i[col]=i[col].dt.total_seconds()
# Out:
# /tmp/ipython-input-11-2405763166.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   i[col]=i[col].dt.total_seconds()

# %%
laps_r['Sector1Time']=laps_r['Sector1Time'].fillna(laps_r['Sector1Time'].mean())
laps_r['Sector3Time']=laps_r['Sector3Time'].fillna(laps_r['Sector3Time'].mean())
laps_r['Sector2Time']=laps_r['Sector3Time'].fillna(laps_r['Sector2Time'].mean())
laps_r['LapTime']=laps_r['LapTime'].fillna(laps_r['LapTime'].mean())
laps_r['SpeedFL']=laps_r['SpeedFL'].fillna(laps_r['SpeedFL'].mean())
laps_r['SpeedST']=laps_r['SpeedST'].fillna(laps_r['SpeedST'].mean())
laps_r.isnull().sum()
# Out:
# /tmp/ipython-input-12-2785354042.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_r['Sector1Time']=laps_r['Sector1Time'].fillna(laps_r['Sector1Time'].mean())
# /tmp/ipython-input-12-2785354042.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_r['Sector3Time']=laps_r['Sector3Time'].fillna(laps_r['Sector3Time'].mean())
# /tmp/ipython-input-12-2785354042.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
laps_q['Sector1Time']=laps_q['Sector1Time'].fillna(laps_q['Sector1Time'].mean())
laps_q['Sector3Time']=laps_q['Sector3Time'].fillna(laps_q['Sector3Time'].mean())
laps_q['Sector2Time']=laps_q['Sector3Time'].fillna(laps_q['Sector2Time'].mean())
laps_q['LapTime']=laps_q['LapTime'].fillna(laps_q['LapTime'].mean())
laps_q['SpeedFL']=laps_q['SpeedFL'].fillna(laps_q['SpeedFL'].mean())
laps_q['SpeedST']=laps_q['SpeedST'].fillna(laps_q['SpeedST'].mean())
laps_q.isnull().sum()
# Out:
# /tmp/ipython-input-13-1872029179.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_q['Sector1Time']=laps_q['Sector1Time'].fillna(laps_q['Sector1Time'].mean())
# /tmp/ipython-input-13-1872029179.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_q['Sector3Time']=laps_q['Sector3Time'].fillna(laps_q['Sector3Time'].mean())
# /tmp/ipython-input-13-1872029179.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
res_q.drop("GridPosition",axis=1,inplace=True)
res_q.rename(columns={'Position':'GridPosition'},inplace=True)
res_q.columns
# Out:
# /tmp/ipython-input-87-382759936.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_q.drop("GridPosition",axis=1,inplace=True)
# /tmp/ipython-input-87-382759936.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_q.rename(columns={'Position':'GridPosition'},inplace=True)
# Index(['DriverNumber', 'Q1', 'Q2', 'Q3', 'GridPosition'], dtype='object')

# %%
res_q
for i in [res_q,res_r]:
  i['Q1']=i['Q1'].dt.total_seconds()
  i['Q2']=i['Q2'].dt.total_seconds()
  i['Q3']=i['Q3'].dt.total_seconds()
# Out:
# /tmp/ipython-input-89-511975177.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   i['Q1']=i['Q1'].dt.total_seconds()
# /tmp/ipython-input-89-511975177.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   i['Q2']=i['Q2'].dt.total_seconds()
# /tmp/ipython-input-89-511975177.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
res_q['Q2']=res_q['Q2'].fillna(0)
res_q['Q3']=res_q['Q3'].fillna(0)
res_q.isnull().sum()
# Out:
# /tmp/ipython-input-90-4252893840.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_q['Q2']=res_q['Q2'].fillna(0)
# /tmp/ipython-input-90-4252893840.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_q['Q3']=res_q['Q3'].fillna(0)
# DriverNumber    0
# Q1              0
# Q2              0
# Q3              0
# GridPosition    0
# dtype: int64

# %%
laps_q=laps_q.groupby('DriverNumber').agg({"LapTime":'mean',"Sector1Time":'mean',"Sector2Time":'mean',"Sector3Time":'mean',"SpeedST":'mean',"SpeedFL":'mean'}).reset_index()
laps_r=laps_r.groupby('DriverNumber').agg({"LapTime":'mean',"Sector1Time":'mean',"Sector2Time":'mean',"Sector3Time":'mean',"SpeedST":'mean',"SpeedFL":'mean'}).reset_index()

# %%
final_df=pd.merge(res_q,laps_q,left_on='DriverNumber', right_on='DriverNumber', how='outer')
final_df
# Out:
#    DriverNumber      Q1      Q2      Q3  GridPosition    LapTime  Sector1Time  \
# 0             1  72.360  72.549  72.000           2.0  90.123407    27.663000
# 1            10  73.289  72.940   0.000          15.0  86.362944    25.234933
# 2            11  73.326   0.000   0.000          16.0  91.881436    28.234909
# 3            14  73.117  72.635  72.228           6.0  88.308060    26.855913
# 4            16  73.107  72.691   0.000          11.0  89.232705    26.591143
# 5            18  73.088  72.659  72.701           9.0  87.510496    27.857080
# 6             2  73.063  72.736   0.000          13.0  89.399509    25.667682
# 7            20  73.217  72.916   0.000          14.0  87.899037    25.824188
# 8            22  72.748  72.303  72.414           8.0  87.127183    26.788917
# 9            23  72.896  72.485  72.796          10.0  86.997861    26.341692
# 10           24  74.292   0.000   0.000          20.0  85.503836    24.664436
# ...

# %%
data_q_25=get_session(2025,"Canada",'Q')
data_r_25=get_session(2025,"Canada",'R')
data_q_25.load()
data_r_25.load()
laps_q_25=data_q_25.laps
laps_r_25=data_r_25.laps
res_q_25=data_q_25.results
res_r_25=data_r_25.results
# Out:
# core           INFO 	Loading data for Canadian Grand Prix - Qualifying [v3.5.3]
# INFO:fastf1.fastf1.core:Loading data for Canadian Grand Prix - Qualifying [v3.5.3]
# req            INFO 	Using cached data for session_info
# INFO:fastf1.fastf1.req:Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# INFO:fastf1.fastf1.req:Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# INFO:fastf1.fastf1.req:Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# INFO:fastf1.fastf1.req:Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# INFO:fastf1.fastf1.req:Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# INFO:fastf1.fastf1.req:Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# ...

# %%
res_q_25['Q3'] = res_q_25['Q3'].dt.total_seconds()
res_q_25['Q2'] = res_q_25['Q2'].dt.total_seconds()
res_q_25['Q1'] = res_q_25['Q1'].dt.total_seconds()
res_r_25['Q3'] = res_r_25['Q3'].dt.total_seconds()
res_r_25['Q2'] = res_r_25['Q2'].dt.total_seconds()
res_r_25['Q1'] = res_r_25['Q1'].dt.total_seconds()
res_q_25.drop('GridPosition',axis=1,inplace=True)
res_q_25.rename(columns={'Position':'GridPosition'},inplace=True)
res_q_25=res_q_25[['DriverNumber','Q1','Q2','Q3','GridPosition']]
res_r_25=res_r_25[['DriverNumber','Q1','Q2','Q3','GridPosition']]

# %%
res_q_25.columns
# Out:
# Index(['DriverNumber', 'Q1', 'Q2', 'Q3', 'GridPosition'], dtype='object')

# %%
res_q_25['Q2']=res_q_25['Q2'].fillna(0)
res_q_25['Q3']=res_q_25['Q3'].fillna(0)
res_q_25.isnull().sum()
# Out:
# /tmp/ipython-input-53-4146415017.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_q_25['Q2']=res_q_25['Q2'].fillna(0)
# /tmp/ipython-input-53-4146415017.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_q_25['Q3']=res_q_25['Q3'].fillna(0)
# DriverNumber    0
# Q1              0
# Q2              0
# Q3              0
# GridPosition    0
# dtype: int64

# %%
res_r_25=res_r_25[['DriverNumber','Q1','Q2','Q3','GridPosition']]
res_r_25['Q2']=res_r_25['Q2'].fillna(0)
res_r_25['Q3']=res_r_25['Q3'].fillna(0)
res_r_25['Q1']=res_r_25['Q1'].fillna(0)
res_r_25.isnull().sum()
# Out:
# DriverNumber    0
# Q1              0
# Q2              0
# Q3              0
# GridPosition    0
# dtype: int64

# %%
laps_q_25=laps_q_25[['DriverNumber','LapTime','Sector1Time','Sector2Time','Sector3Time','SpeedFL','SpeedST']]
laps_r_25=laps_r_25[['DriverNumber','LapTime','Sector1Time','Sector2Time','Sector3Time','SpeedFL','SpeedST']]
for i in [laps_r_25,laps_q_25]:
 for col in ['LapTime','Sector1Time','Sector2Time','Sector3Time']:
  i[col]=i[col].dt.total_seconds()
  i[col]=i[col].fillna(i[col].mean())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-38-2124944302.py in <cell line: 0>()
#       3 for i in [laps_r_25,laps_q_25]:
#       4  for col in ['LapTime','Sector1Time','Sector2Time','Sector3Time']:
# ----> 5   i[col]=i[col].dt.total_seconds()
#       6   i[col]=i[col].fillna(i[col].mean())
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#    6300
#    6301     @final
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/accessor.py in __get__(self, obj, cls)
#     222             # we're accessing the attribute of the class, i.e., Dataset.geo
#     223             return self._accessor
# --> 224         accessor_obj = self._accessor(obj)
# ...

# %%
'''laps_r_25['Sector3Time']=laps_r_25['Sector3Time'].dt.total_seconds()
laps_q_25['Sector3Time']=laps_q_25['Sector3Time'].dt.total_seconds()
laps_q_25['Sector2Time']=laps_q_25['Sector2Time'].dt.total_seconds()
laps_q_25['Sector1Time']=laps_q_25['Sector1Time'].dt.total_seconds()
laps_q_25['LapTime']=laps_q_25['LapTime'].dt.total_seconds()'''
laps_r_25['Sector3Time']=laps_r_25['Sector3Time'].fillna(laps_r_25['Sector3Time'].mean())
for i in [laps_q_25]:
 for col in ['LapTime','Sector1Time','Sector2Time','Sector3Time']:
  i[col]=i[col].fillna(i[col].mean())

# %%
laps_r_25['SpeedFL']=laps_r_25['SpeedFL'].fillna(laps_r_25['SpeedFL'].mean())
laps_r_25['SpeedST']=laps_r_25['SpeedST'].fillna(laps_r_25['SpeedST'].mean())
laps_r_25.isnull().sum()
# Out:
# DriverNumber    0
# LapTime         0
# Sector1Time     0
# Sector2Time     0
# Sector3Time     0
# SpeedFL         0
# SpeedST         0
# dtype: int64

# %%
laps_q_25['SpeedFL']=laps_q_25['SpeedFL'].fillna(laps_q_25['SpeedFL'].mean())
laps_q_25['SpeedST']=laps_q_25['SpeedST'].fillna(laps_q_25['SpeedST'].mean())
laps_q_25.isnull().sum()
# Out:
# DriverNumber    0
# LapTime         0
# Sector1Time     0
# Sector2Time     0
# Sector3Time     0
# SpeedFL         0
# SpeedST         0
# dtype: int64

# %%
res_q_25
# Out:
#    DriverNumber      Q1      Q2      Q3  GridPosition
# 63           63  72.075  71.570  70.899           1.0
# 1             1  72.054  71.638  71.059           2.0
# 81           81  71.939  71.715  71.120           3.0
# 12           12  72.279  71.974  71.391           4.0
# 44           44  71.952  71.885  71.526           5.0
# 14           14  72.073  71.805  71.586           6.0
# 4             4  71.826  71.599  71.625           7.0
# 16           16  72.038  71.626  71.682           8.0
# 6             6  72.211  72.003  71.867           9.0
# 23           23  72.090  71.892  71.907          10.0
# 22           22  72.334  72.102   0.000          11.0
# 43           43  72.234  72.142   0.000          12.0
# 27           27  72.323  72.183   0.000          13.0
# 87           87  72.306  72.340   0.000          14.0
# 31           31  72.378  72.634   0.000          15.0
# 5             5  72.385   0.000   0.000          16.0
# ...

# %%
laps_q_25.columns
# Out:
# Index(['DriverNumber', 'LapTime', 'Sector1Time', 'Sector2Time', 'Sector3Time',
#        'SpeedST', 'SpeedFL'],
#       dtype='object')

# %%
print(res_q_25.columns)
print(laps_q_25.columns)
laps_q_25=laps_q_25.groupby('DriverNumber').agg({"LapTime":'mean',"Sector1Time":'mean',"Sector2Time":'mean',"Sector3Time":'mean',"SpeedST":'mean',"SpeedFL":'mean'}).reset_index()
test_df=pd.merge(res_q_25,laps_q_25,left_on='DriverNumber', right_on='DriverNumber', how='outer')
final_df
# Out:
# Index(['DriverNumber', 'Q1', 'Q2', 'Q3', 'GridPosition'], dtype='object')
# Index(['DriverNumber', 'LapTime', 'Sector1Time', 'Sector2Time', 'Sector3Time',
#        'SpeedST', 'SpeedFL'],
#       dtype='object')
#    DriverNumber      Q1      Q2      Q3  GridPosition    LapTime  Sector1Time  \
# 0             1  72.360  72.549  72.000           2.0  90.123407    27.663000
# 1            10  73.289  72.940   0.000          15.0  86.362944    25.234933
# 2            11  73.326   0.000   0.000          16.0  91.881436    28.234909
# 3            14  73.117  72.635  72.228           6.0  88.308060    26.855913
# 4            16  73.107  72.691   0.000          11.0  89.232705    26.591143
# 5            18  73.088  72.659  72.701           9.0  87.510496    27.857080
# 6             2  73.063  72.736   0.000          13.0  89.399509    25.667682
# 7            20  73.217  72.916   0.000          14.0  87.899037    25.824188
# ...

# %%
X_train=final_df
y_train=res_r['Position']
#X_train=X_train.drop(X_train.columns[1],axis=1)
X_train.isnull().sum()
# Out:
# DriverNumber    0
# Q1              0
# Q2              0
# Q3              0
# GridPosition    0
# LapTime         0
# Sector1Time     0
# Sector2Time     0
# Sector3Time     0
# SpeedST         0
# SpeedFL         0
# dtype: int64

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import GradientBoostingRegressor
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
model= GradientBoostingRegressor(n_estimators=100, learning_rate=1.0,max_depth=3, random_state=0)
model.fit(X_train_scaled,y_train)
# Out:
# GradientBoostingRegressor(learning_rate=1.0, random_state=0)

# %%
print(test_df.columns)
print(X_train.columns)
# Out:
# Index(['DriverNumber', 'Q1', 'Q2', 'Q3', 'GridPosition', 'LapTime',
#        'Sector1Time', 'Sector2Time', 'Sector3Time', 'SpeedST', 'SpeedFL'],
#       dtype='object')
# Index(['DriverNumber', 'Q1', 'Q2', 'Q3', 'GridPosition', 'LapTime',
#        'Sector1Time', 'Sector2Time', 'Sector3Time', 'SpeedST', 'SpeedFL'],
#       dtype='object')

# %%
X_2025=test_df
y_pred=model.predict(X_2025)
y_pred
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but GradientBoostingRegressor was fitted without feature names
#   warnings.warn(
# array([16.4219657 , 18.43797726, 18.41994779, 18.41994779, 18.41994779,
#        18.43797726, 18.41993912, 18.41994779, 18.41993912, 18.43797726,
#        18.41993912, 18.41994779, 18.41993912, 18.41994779, 18.43797726,
#        18.43797726, 18.41994779, 18.483852  , 18.41994779, 18.41993912])

# %%
laps_q_25['PredictedScore'] = y_pred
laps_q_25
# Out:
#    DriverNumber    LapTime  Sector1Time  Sector2Time  Sector3Time     SpeedST  \
# 0             1  82.623077    24.536250    25.539650    33.142569  275.150000
# 1            10  86.133522    27.002417    25.470917    33.466308  282.888158
# 2            12  87.911073    28.678095    26.286190    33.590971  278.238095
# 3            14  85.849946    25.761741    25.884977    33.764977  265.394737
# 4            16  87.319727    25.907326    26.548074    33.865533  272.802144
# 5            18  91.110265    27.502983    26.175115    37.715039  265.971491
# 6            22  87.213096    28.730600    26.339067    33.111944  285.066667
# 7            23  87.368451    24.914353    25.749646    36.921905  293.421930
# 8            27  88.386020    26.233389    26.361833    35.668718  262.444444
# 9            30  91.486618    29.110300    27.582000    35.020446  236.500000
# 10           31  87.274398    26.006276    26.144161    35.211187  268.745614
# ...

# %%
winner_row = laps_q_25.loc[laps_q_25['PredictedScore'].idxmax()]
num=winner_row['DriverNumber']
print(num)
# Out:
# 63

# %% [markdown]
# Driver Number 63 belongs to George Russell who won Canadian Grand Prix 2025
